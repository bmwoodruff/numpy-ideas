# %%
from sphinx.ext.intersphinx import InventoryFile
from io import BytesIO

def read_objects_inv(file_path):
    try:
        with open(file_path, 'rb') as file:
            data = file.read()
        return data
    except FileNotFoundError:
        print(f"The file {file_path} does not exist.")
        return None

def parse_objects_inv(data):
    # Use InventoryFile to parse the inventory
    inv_file = InventoryFile.load(BytesIO(data), '', lambda uri, rel: rel)
    
    inventory = {}
    for project_name, project_data in inv_file.items():
        inventory[project_name] = {}
        for name, (project, version, uri, display_name) in project_data.items():
            inventory[project_name][name] = (uri, display_name)
    return inventory

def save_inventory_to_file(inventory, filename):
    with open(filename, 'w', encoding='utf-8') as file:
        for category, items in inventory.items():
            file.write(f"\nCategory: {category}\n")
            for name, (location, dispname) in items.items():
                file.write(f"  {name} -> {location} ({dispname})\n")

def get_inventory_as_text(inventory):
    inventory_text = ""
    for category, items in inventory.items():
        inventory_text += f"\nCategory: {category}\n"
        for name, (location, dispname) in items.items():
            inventory_text += f"  {name} -> {location} ({dispname})\n"
    return inventory_text
    
def print_inventory(file_path, output_filename):
    data = read_objects_inv(file_path)
    if data:
        inventory = parse_objects_inv(data)
        save_inventory_to_file(inventory, output_filename)
        print(f"Inventory saved to {output_filename}")

def get_inventory_text(file_path):
    data = read_objects_inv(file_path)
    if data:
        inventory = parse_objects_inv(data)
        return get_inventory_as_text(inventory)
    else:
        return "Error: Could not read the objects.inv file."


# Path to the local objects.inv file
local_file_path = './../doc/build/html/objects.inv'
# Output file name
output_filename = 'inventory2.txt'

# Print the inventory
print_inventory(local_file_path, output_filename)

# Get the inventory as text
inventory_text = get_inventory_text(local_file_path)
print(inventory_text)
# Out:
# Inventory saved to inventory2.txt
#
# Category: c:macro
#   NO_IMPORT_ARRAY -> reference/c-api/array.html#c.NO_IMPORT_ARRAY (-)
#   NO_IMPORT_UFUNC -> reference/c-api/ufunc.html#c.NO_IMPORT_UFUNC (-)
#   NPY_1_PI -> reference/c-api/coremath.html#c.NPY_1_PI (-)
#   NPY_2_PI -> reference/c-api/coremath.html#c.NPY_2_PI (-)
#   NPY_ALLOW_C_API -> reference/c-api/array.html#c.NPY_ALLOW_C_API (-)
#   NPY_ALLOW_C_API_DEF -> reference/c-api/array.html#c.NPY_ALLOW_C_API_DEF (-)
#   NPY_ALLOW_THREADS -> reference/c-api/array.html#c.NPY_ALLOW_THREADS (-)
#   NPY_API_SYMBOL_ATTRIBUTE -> reference/c-api/array.html#c.NPY_API_SYMBOL_ATTRIBUTE (-)
#   NPY_ARRAY_ALIGNED -> reference/c-api/array.html#c.NPY_ARRAY_ALIGNED (-)
#   NPY_ARRAY_BEHAVED -> reference/c-api/array.html#c.NPY_ARRAY_BEHAVED (-)
#   NPY_ARRAY_BEHAVED_NS -> reference/c-api/array.html#c.NPY_ARRAY_BEHAVED_NS (-)
#   NPY_ARRAY_CARRAY -> reference/c-api/array.html#c.NPY_ARRAY_CARRAY (-)
#   NPY_ARRAY_CARRAY_RO -> reference/c-api/array.html#c.NPY_ARRAY_CARRAY_RO (-)
#   NPY_ARRAY_C_CONTIGUOUS -> reference/c-api/array.html#c.NPY_ARRAY_C_CONTIGUOUS (-)
#   NPY_ARRAY_DEFAULT -> reference/c-api/array.html#c.NPY_ARRAY_DEFAULT (-)
#   NPY_ARRAY_ELEMENTSTRIDES -> reference/c-api/array.html#c.NPY_ARRAY_ELEMENTSTRIDES (-)
#   NPY_ARRAY_ENSUREARRAY -> reference/c-api/array.html#c.NPY_ARRAY_ENSUREARRAY (-)
#   NPY_ARRAY_ENSURECOPY -> reference/c-api/array.html#c.NPY_ARRAY_ENSURECOPY (-)
#   NPY_ARRAY_FARRAY -> reference/c-api/array.html#c.NPY_ARRAY_FARRAY (-)
#   NPY_ARRAY_FARRAY_RO -> reference/c-api/array.html#c.NPY_ARRAY_FARRAY_RO (-)
#   NPY_ARRAY_FORCECAST -> reference/c-api/array.html#c.NPY_ARRAY_FORCECAST (-)
#   NPY_ARRAY_F_CONTIGUOUS -> reference/c-api/array.html#c.NPY_ARRAY_F_CONTIGUOUS (-)
#   NPY_ARRAY_INOUT_ARRAY -> reference/c-api/array.html#c.NPY_ARRAY_INOUT_ARRAY (-)
#   NPY_ARRAY_INOUT_FARRAY -> reference/c-api/array.html#c.NPY_ARRAY_INOUT_FARRAY (-)
#   NPY_ARRAY_IN_ARRAY -> reference/c-api/array.html#c.NPY_ARRAY_IN_ARRAY (-)
#   NPY_ARRAY_IN_FARRAY -> reference/c-api/array.html#c.NPY_ARRAY_IN_FARRAY (-)
#   NPY_ARRAY_NOTSWAPPED -> reference/c-api/array.html#c.NPY_ARRAY_NOTSWAPPED (-)
#   NPY_ARRAY_OUT_ARRAY -> reference/c-api/array.html#c.NPY_ARRAY_OUT_ARRAY (-)
#   NPY_ARRAY_OUT_FARRAY -> reference/c-api/array.html#c.NPY_ARRAY_OUT_FARRAY (-)
#   NPY_ARRAY_OWNDATA -> reference/c-api/array.html#c.NPY_ARRAY_OWNDATA (-)
#   NPY_ARRAY_UPDATE_ALL -> reference/c-api/array.html#c.NPY_ARRAY_UPDATE_ALL (-)
#   NPY_ARRAY_WRITEABLE -> reference/c-api/array.html#c.NPY_ARRAY_WRITEABLE (-)
#   NPY_ARRAY_WRITEBACKIFCOPY -> reference/c-api/array.html#c.NPY_ARRAY_WRITEBACKIFCOPY (-)
#   NPY_ARR_HAS_DESCR -> reference/arrays.interface.html#c.NPY_ARR_HAS_DESCR (-)
#   NPY_BEGIN_ALLOW_THREADS -> reference/c-api/array.html#c.NPY_BEGIN_ALLOW_THREADS (-)
#   NPY_BEGIN_THREADS -> reference/c-api/array.html#c.NPY_BEGIN_THREADS (-)
#   NPY_BEGIN_THREADS_DEF -> reference/c-api/array.html#c.NPY_BEGIN_THREADS_DEF (-)
#   NPY_BIG -> reference/c-api/array.html#c.NPY_BIG (-)
#   NPY_BIG_ENDIAN -> reference/c-api/config.html#c.NPY_BIG_ENDIAN (-)
#   NPY_BUFSIZE -> reference/c-api/array.html#c.NPY_BUFSIZE (-)
#   NPY_BYTE_ORDER -> reference/c-api/config.html#c.NPY_BYTE_ORDER (-)
#   NPY_CPU_AMD64 -> reference/c-api/config.html#c.NPY_CPU_AMD64 (-)
#   NPY_CPU_IA64 -> reference/c-api/config.html#c.NPY_CPU_IA64 (-)
#   NPY_CPU_PARISC -> reference/c-api/config.html#c.NPY_CPU_PARISC (-)
#   NPY_CPU_PPC -> reference/c-api/config.html#c.NPY_CPU_PPC (-)
#   NPY_CPU_PPC64 -> reference/c-api/config.html#c.NPY_CPU_PPC64 (-)
#   NPY_CPU_S390 -> reference/c-api/config.html#c.NPY_CPU_S390 (-)
#   NPY_CPU_SPARC -> reference/c-api/config.html#c.NPY_CPU_SPARC (-)
#   NPY_CPU_SPARC64 -> reference/c-api/config.html#c.NPY_CPU_SPARC64 (-)
#   NPY_CPU_X86 -> reference/c-api/config.html#c.NPY_CPU_X86 (-)
#   NPY_DISABLE_C_API -> reference/c-api/array.html#c.NPY_DISABLE_C_API (-)
#   NPY_DTYPE -> reference/c-api/array.html#c.NPY_DTYPE (-)
#   NPY_DT_ABSTRACT -> reference/c-api/array.html#c.NPY_DT_ABSTRACT (-)
#   NPY_DT_NUMERIC -> reference/c-api/array.html#c.NPY_DT_NUMERIC (-)
#   NPY_DT_PARAMETRIC -> reference/c-api/array.html#c.NPY_DT_PARAMETRIC (-)
#   NPY_DT_PyArray_ArrFuncs_argmax -> reference/c-api/array.html#c.NPY_DT_PyArray_ArrFuncs_argmax (-)
#   NPY_DT_PyArray_ArrFuncs_argmin -> reference/c-api/array.html#c.NPY_DT_PyArray_ArrFuncs_argmin (-)
#   NPY_DT_PyArray_ArrFuncs_argsort -> reference/c-api/array.html#c.NPY_DT_PyArray_ArrFuncs_argsort (-)
#   NPY_DT_PyArray_ArrFuncs_compare -> reference/c-api/array.html#c.NPY_DT_PyArray_ArrFuncs_compare (-)
#   NPY_DT_PyArray_ArrFuncs_dotfunc -> reference/c-api/array.html#c.NPY_DT_PyArray_ArrFuncs_dotfunc (-)
#   NPY_DT_PyArray_ArrFuncs_fill -> reference/c-api/array.html#c.NPY_DT_PyArray_ArrFuncs_fill (-)
#   NPY_DT_PyArray_ArrFuncs_fillwithscalar -> reference/c-api/array.html#c.NPY_DT_PyArray_ArrFuncs_fillwithscalar (-)
#   NPY_DT_PyArray_ArrFuncs_fromstr -> reference/c-api/array.html#c.NPY_DT_PyArray_ArrFuncs_fromstr (-)
#   NPY_DT_PyArray_ArrFuncs_getitem -> reference/c-api/array.html#c.NPY_DT_PyArray_ArrFuncs_getitem (-)
#   NPY_DT_PyArray_ArrFuncs_nonzero -> reference/c-api/array.html#c.NPY_DT_PyArray_ArrFuncs_nonzero (-)
#   NPY_DT_PyArray_ArrFuncs_scanfunc -> reference/c-api/array.html#c.NPY_DT_PyArray_ArrFuncs_scanfunc (-)
#   NPY_DT_PyArray_ArrFuncs_setitem -> reference/c-api/array.html#c.NPY_DT_PyArray_ArrFuncs_setitem (-)
#   NPY_DT_PyArray_ArrFuncs_sort -> reference/c-api/array.html#c.NPY_DT_PyArray_ArrFuncs_sort (-)
#   NPY_DT_common_dtype -> reference/c-api/array.html#c.NPY_DT_common_dtype (-)
#   NPY_DT_common_instance -> reference/c-api/array.html#c.NPY_DT_common_instance (-)
#   NPY_DT_default_descr -> reference/c-api/array.html#c.NPY_DT_default_descr (-)
#   NPY_DT_discover_descr_from_pyobject -> reference/c-api/array.html#c.NPY_DT_discover_descr_from_pyobject (-)
#   NPY_DT_ensure_canonical -> reference/c-api/array.html#c.NPY_DT_ensure_canonical (-)
#   NPY_DT_finalize_descr -> reference/c-api/array.html#c.NPY_DT_finalize_descr (-)
#   NPY_DT_get_clear_loop -> reference/c-api/array.html#c.NPY_DT_get_clear_loop (-)
#   NPY_DT_get_fill_zero_loop -> reference/c-api/array.html#c.NPY_DT_get_fill_zero_loop (-)
#   NPY_DT_getitem -> reference/c-api/array.html#c.NPY_DT_getitem (-)
#   NPY_DT_setitem -> reference/c-api/array.html#c.NPY_DT_setitem (-)
#   NPY_E -> reference/c-api/coremath.html#c.NPY_E (-)
#   NPY_END_ALLOW_THREADS -> reference/c-api/array.html#c.NPY_END_ALLOW_THREADS (-)
#   NPY_END_THREADS -> reference/c-api/array.html#c.NPY_END_THREADS (-)
#   NPY_EULER -> reference/c-api/coremath.html#c.NPY_EULER (-)
#   NPY_FAIL -> reference/c-api/array.html#c.NPY_FAIL (-)
#   NPY_FALSE -> reference/c-api/array.html#c.NPY_FALSE (-)
#   NPY_FEATURE_VERSION -> reference/c-api/array.html#c.NPY_FEATURE_VERSION (-)
#   NPY_FROM_FIELDS -> reference/c-api/types-and-structures.html#c.NPY_FROM_FIELDS (-)
#   NPY_HALF_NAN -> reference/c-api/coremath.html#c.NPY_HALF_NAN (-)
#   NPY_HALF_NEGONE -> reference/c-api/coremath.html#c.NPY_HALF_NEGONE (-)
#   NPY_HALF_NINF -> reference/c-api/coremath.html#c.NPY_HALF_NINF (-)
#   NPY_HALF_NZERO -> reference/c-api/coremath.html#c.NPY_HALF_NZERO (-)
#   NPY_HALF_ONE -> reference/c-api/coremath.html#c.NPY_HALF_ONE (-)
#   NPY_HALF_PINF -> reference/c-api/coremath.html#c.NPY_HALF_PINF (-)
#   NPY_HALF_PZERO -> reference/c-api/coremath.html#c.NPY_HALF_PZERO (-)
#   NPY_HALF_ZERO -> reference/c-api/coremath.html#c.NPY_HALF_ZERO (-)
#   NPY_IGNORE -> reference/c-api/array.html#c.NPY_IGNORE (-)
#   NPY_INFINITY -> reference/c-api/coremath.html#c.NPY_INFINITY (-)
#   NPY_INTP_FMT -> reference/c-api/dtype.html#c.NPY_INTP_FMT (-)
#   NPY_ITEM_HASOBJECT -> reference/c-api/types-and-structures.html#c.NPY_ITEM_HASOBJECT (-)
#   NPY_ITEM_IS_POINTER -> reference/c-api/types-and-structures.html#c.NPY_ITEM_IS_POINTER (-)
#   NPY_ITEM_REFCOUNT -> reference/c-api/types-and-structures.html#c.NPY_ITEM_REFCOUNT (-)
#   NPY_ITER_ALIGNED -> reference/c-api/iterator.html#c.NPY_ITER_ALIGNED (-)
#   NPY_ITER_ALLOCATE -> reference/c-api/iterator.html#c.NPY_ITER_ALLOCATE (-)
#   NPY_ITER_ARRAYMASK -> reference/c-api/iterator.html#c.NPY_ITER_ARRAYMASK (-)
#   NPY_ITER_BUFFERED -> reference/c-api/iterator.html#c.NPY_ITER_BUFFERED (-)
#   NPY_ITER_COMMON_DTYPE -> reference/c-api/iterator.html#c.NPY_ITER_COMMON_DTYPE (-)
#   NPY_ITER_CONTIG -> reference/c-api/iterator.html#c.NPY_ITER_CONTIG (-)
#   NPY_ITER_COPY -> reference/c-api/iterator.html#c.NPY_ITER_COPY (-)
#   NPY_ITER_COPY_IF_OVERLAP -> reference/c-api/iterator.html#c.NPY_ITER_COPY_IF_OVERLAP (-)
#   NPY_ITER_C_INDEX -> reference/c-api/iterator.html#c.NPY_ITER_C_INDEX (-)
#   NPY_ITER_DELAY_BUFALLOC -> reference/c-api/iterator.html#c.NPY_ITER_DELAY_BUFALLOC (-)
#   NPY_ITER_DONT_NEGATE_STRIDES -> reference/c-api/iterator.html#c.NPY_ITER_DONT_NEGATE_STRIDES (-)
#   NPY_ITER_EXTERNAL_LOOP -> reference/c-api/iterator.html#c.NPY_ITER_EXTERNAL_LOOP (-)
#   NPY_ITER_F_INDEX -> reference/c-api/iterator.html#c.NPY_ITER_F_INDEX (-)
#   NPY_ITER_GROWINNER -> reference/c-api/iterator.html#c.NPY_ITER_GROWINNER (-)
#   NPY_ITER_MULTI_INDEX -> reference/c-api/iterator.html#c.NPY_ITER_MULTI_INDEX (-)
#   NPY_ITER_NBO -> reference/c-api/iterator.html#c.NPY_ITER_NBO (-)
#   NPY_ITER_NO_BROADCAST -> reference/c-api/iterator.html#c.NPY_ITER_NO_BROADCAST (-)
#   NPY_ITER_NO_SUBTYPE -> reference/c-api/iterator.html#c.NPY_ITER_NO_SUBTYPE (-)
#   NPY_ITER_OVERLAP_ASSUME_ELEMENTWISE -> reference/c-api/iterator.html#c.NPY_ITER_OVERLAP_ASSUME_ELEMENTWISE (-)
#   NPY_ITER_RANGED -> reference/c-api/iterator.html#c.NPY_ITER_RANGED (-)
#   NPY_ITER_READONLY -> reference/c-api/iterator.html#c.NPY_ITER_READONLY (-)
#   NPY_ITER_READWRITE -> reference/c-api/iterator.html#c.NPY_ITER_READWRITE (-)
#   NPY_ITER_REDUCE_OK -> reference/c-api/iterator.html#c.NPY_ITER_REDUCE_OK (-)
#   NPY_ITER_REFS_OK -> reference/c-api/iterator.html#c.NPY_ITER_REFS_OK (-)
#   NPY_ITER_UPDATEIFCOPY -> reference/c-api/iterator.html#c.NPY_ITER_UPDATEIFCOPY (-)
#   NPY_ITER_WRITEMASKED -> reference/c-api/iterator.html#c.NPY_ITER_WRITEMASKED (-)
#   NPY_ITER_WRITEONLY -> reference/c-api/iterator.html#c.NPY_ITER_WRITEONLY (-)
#   NPY_ITER_ZEROSIZE_OK -> reference/c-api/iterator.html#c.NPY_ITER_ZEROSIZE_OK (-)
#   NPY_LIKELY -> reference/c-api/config.html#c.NPY_LIKELY (-)
#   NPY_LIST_PICKLE -> reference/c-api/types-and-structures.html#c.NPY_LIST_PICKLE (-)
#   NPY_LITTLE -> reference/c-api/array.html#c.NPY_LITTLE (-)
#   NPY_LITTLE_ENDIAN -> reference/c-api/config.html#c.NPY_LITTLE_ENDIAN (-)
#   NPY_LOG10E -> reference/c-api/coremath.html#c.NPY_LOG10E (-)
#   NPY_LOG2E -> reference/c-api/coremath.html#c.NPY_LOG2E (-)
#   NPY_LOGE10 -> reference/c-api/coremath.html#c.NPY_LOGE10 (-)
#   NPY_LOGE2 -> reference/c-api/coremath.html#c.NPY_LOGE2 (-)
#   NPY_LONGDOUBLE_FMT -> reference/c-api/dtype.html#c.NPY_LONGDOUBLE_FMT (-)
#   NPY_LONGLONG_FMT -> reference/c-api/dtype.html#c.NPY_LONGLONG_FMT (-)
#   NPY_LOOP_BEGIN_THREADS -> reference/c-api/ufunc.html#c.NPY_LOOP_BEGIN_THREADS (-)
#   NPY_LOOP_END_THREADS -> reference/c-api/ufunc.html#c.NPY_LOOP_END_THREADS (-)
#   NPY_MAXARGS -> reference/c-api/array.html#c.NPY_MAXARGS (-)
#   NPY_MAXDIMS -> reference/c-api/array.html#c.NPY_MAXDIMS (-)
#   NPY_MAX_BUFSIZE -> reference/c-api/array.html#c.NPY_MAX_BUFSIZE (-)
#   NPY_METH_contiguous_indexed_loop -> reference/c-api/array.html#c.NPY_METH_contiguous_indexed_loop (-)
#   NPY_METH_contiguous_loop -> reference/c-api/array.html#c.NPY_METH_contiguous_loop (-)
#   NPY_METH_get_loop -> reference/c-api/array.html#c.NPY_METH_get_loop (-)
#   NPY_METH_get_reduction_initial -> reference/c-api/array.html#c.NPY_METH_get_reduction_initial (-)
#   NPY_METH_resolve_descriptors -> reference/c-api/array.html#c.NPY_METH_resolve_descriptors (-)
#   NPY_METH_strided_loop -> reference/c-api/array.html#c.NPY_METH_strided_loop (-)
#   NPY_METH_unaligned_contiguous_loop -> reference/c-api/array.html#c.NPY_METH_unaligned_contiguous_loop (-)
#   NPY_METH_unaligned_strided_loop -> reference/c-api/array.html#c.NPY_METH_unaligned_strided_loop (-)
#   NPY_MIN_BUFSIZE -> reference/c-api/array.html#c.NPY_MIN_BUFSIZE (-)
#   NPY_NAN -> reference/c-api/coremath.html#c.NPY_NAN (-)
#   NPY_NATIVE -> reference/c-api/array.html#c.NPY_NATIVE (-)
#   NPY_NEEDS_INIT -> reference/c-api/types-and-structures.html#c.NPY_NEEDS_INIT (-)
#   NPY_NEEDS_PYAPI -> reference/c-api/types-and-structures.html#c.NPY_NEEDS_PYAPI (-)
#   NPY_NOTYPE -> reference/c-api/dtype.html#c.NPY_NOTYPE (-)
#   NPY_NTYPES_LEGACY -> reference/c-api/dtype.html#c.NPY_NTYPES_LEGACY (-)
#   NPY_NUM_FLOATTYPE -> reference/c-api/array.html#c.NPY_NUM_FLOATTYPE (-)
#   NPY_NZERO -> reference/c-api/coremath.html#c.NPY_NZERO (-)
#   NPY_OBJECT_DTYPE_FLAGS -> reference/c-api/types-and-structures.html#c.NPY_OBJECT_DTYPE_FLAGS (-)
#   NPY_PI -> reference/c-api/coremath.html#c.NPY_PI (-)
#   NPY_PI_2 -> reference/c-api/coremath.html#c.NPY_PI_2 (-)
#   NPY_PI_4 -> reference/c-api/coremath.html#c.NPY_PI_4 (-)
#   NPY_PRIORITY -> reference/c-api/array.html#c.NPY_PRIORITY (-)
#   NPY_PZERO -> reference/c-api/coremath.html#c.NPY_PZERO (-)
#   NPY_RAVEL_AXIS -> reference/c-api/array.html#c.NPY_RAVEL_AXIS (-)
#   NPY_SCALAR_PRIORITY -> reference/c-api/array.html#c.NPY_SCALAR_PRIORITY (-)
#   NPY_SIZEOF_DOUBLE -> reference/c-api/config.html#c.NPY_SIZEOF_DOUBLE (-)
#   NPY_SIZEOF_FLOAT -> reference/c-api/config.html#c.NPY_SIZEOF_FLOAT (-)
#   NPY_SIZEOF_INT -> reference/c-api/config.html#c.NPY_SIZEOF_INT (-)
#   NPY_SIZEOF_INTP -> reference/c-api/config.html#c.NPY_SIZEOF_INTP (-)
#   NPY_SIZEOF_LONG -> reference/c-api/config.html#c.NPY_SIZEOF_LONG (-)
#   NPY_SIZEOF_LONGDOUBLE -> reference/c-api/config.html#c.NPY_SIZEOF_LONGDOUBLE (-)
#   NPY_SIZEOF_LONGLONG -> reference/c-api/config.html#c.NPY_SIZEOF_LONGLONG (-)
#   NPY_SIZEOF_LONG_DOUBLE -> reference/c-api/config.html#c.NPY_SIZEOF_LONG_DOUBLE (-)
#   NPY_SIZEOF_PY_INTPTR_T -> reference/c-api/config.html#c.NPY_SIZEOF_PY_INTPTR_T (-)
#   NPY_SIZEOF_PY_LONG_LONG -> reference/c-api/config.html#c.NPY_SIZEOF_PY_LONG_LONG (-)
#   NPY_SIZEOF_SHORT -> reference/c-api/config.html#c.NPY_SIZEOF_SHORT (-)
#   NPY_SUBTYPE_PRIORITY -> reference/c-api/array.html#c.NPY_SUBTYPE_PRIORITY (-)
#   NPY_SUCCEED -> reference/c-api/array.html#c.NPY_SUCCEED (-)
#   NPY_SWAP -> reference/c-api/array.html#c.NPY_SWAP (-)
#   NPY_TRUE -> reference/c-api/array.html#c.NPY_TRUE (-)
#   NPY_UINTP_FMT -> reference/c-api/dtype.html#c.NPY_UINTP_FMT (-)
#   NPY_ULONGLONG_FMT -> reference/c-api/dtype.html#c.NPY_ULONGLONG_FMT (-)
#   NPY_UNLIKELY -> reference/c-api/config.html#c.NPY_UNLIKELY (-)
#   NPY_UNUSED -> reference/c-api/config.html#c.NPY_UNUSED (-)
#   NPY_USERDEF -> reference/c-api/dtype.html#c.NPY_USERDEF (-)
#   NPY_USE_GETITEM -> reference/c-api/types-and-structures.html#c.NPY_USE_GETITEM (-)
#   NPY_USE_SETITEM -> reference/c-api/types-and-structures.html#c.NPY_USE_SETITEM (-)
#   NPY_VERSION -> reference/c-api/array.html#c.NPY_VERSION (-)
#   PY_ARRAY_UNIQUE_SYMBOL -> reference/c-api/array.html#c.PY_ARRAY_UNIQUE_SYMBOL (-)
#   PY_UFUNC_UNIQUE_SYMBOL -> reference/c-api/ufunc.html#c.PY_UFUNC_UNIQUE_SYMBOL (-)
#   PyArray_Choose.NPY_CLIP -> reference/c-api/array.html#c.PyArray_Choose.NPY_CLIP (-)
#   PyArray_Choose.NPY_RAISE -> reference/c-api/array.html#c.PyArray_Choose.NPY_RAISE (-)
#   PyArray_Choose.NPY_WRAP -> reference/c-api/array.html#c.PyArray_Choose.NPY_WRAP (-)
#   PyArray_GetEndianness.NPY_CPU_BIG -> reference/c-api/config.html#c.PyArray_GetEndianness.NPY_CPU_BIG (-)
#   PyArray_GetEndianness.NPY_CPU_LITTLE -> reference/c-api/config.html#c.PyArray_GetEndianness.NPY_CPU_LITTLE (-)
#   PyArray_GetEndianness.NPY_CPU_UNKNOWN_ENDIAN -> reference/c-api/config.html#c.PyArray_GetEndianness.NPY_CPU_UNKNOWN_ENDIAN (-)
#   PyArray_IsScalar -> reference/c-api/array.html#c.PyArray_IsScalar (-)
#   PyArray_MAX -> reference/c-api/array.html#c.PyArray_MAX (-)
#   PyArray_MIN -> reference/c-api/array.html#c.PyArray_MIN (-)
#   PyArray_NeighborhoodIterNew.NPY_NEIGHBORHOOD_ITER_CIRCULAR_PADDING -> reference/c-api/array.html#c.PyArray_NeighborhoodIterNew.NPY_NEIGHBORHOOD_ITER_CIRCULAR_PADDING (-)
#   PyArray_NeighborhoodIterNew.NPY_NEIGHBORHOOD_ITER_CONSTANT_PADDING -> reference/c-api/array.html#c.PyArray_NeighborhoodIterNew.NPY_NEIGHBORHOOD_ITER_CONSTANT_PADDING (-)
#   PyArray_NeighborhoodIterNew.NPY_NEIGHBORHOOD_ITER_MIRROR_PADDING -> reference/c-api/array.html#c.PyArray_NeighborhoodIterNew.NPY_NEIGHBORHOOD_ITER_MIRROR_PADDING (-)
#   PyArray_NeighborhoodIterNew.NPY_NEIGHBORHOOD_ITER_ONE_PADDING -> reference/c-api/array.html#c.PyArray_NeighborhoodIterNew.NPY_NEIGHBORHOOD_ITER_ONE_PADDING (-)
#   PyArray_NeighborhoodIterNew.NPY_NEIGHBORHOOD_ITER_ZERO_PADDING -> reference/c-api/array.html#c.PyArray_NeighborhoodIterNew.NPY_NEIGHBORHOOD_ITER_ZERO_PADDING (-)
#   PyArray_realloc.NPY_USE_PYMEM -> reference/c-api/array.html#c.PyArray_realloc.NPY_USE_PYMEM (-)
#   PyUFunc_IdentityValue -> reference/c-api/ufunc.html#c.PyUFunc_IdentityValue (-)
#   PyUFunc_MinusOne -> reference/c-api/ufunc.html#c.PyUFunc_MinusOne (-)
#   PyUFunc_None -> reference/c-api/ufunc.html#c.PyUFunc_None (-)
#   PyUFunc_One -> reference/c-api/ufunc.html#c.PyUFunc_One (-)
#   PyUFunc_ReorderableNone -> reference/c-api/ufunc.html#c.PyUFunc_ReorderableNone (-)
#   PyUFunc_Zero -> reference/c-api/ufunc.html#c.PyUFunc_Zero (-)
#   UFUNC_CORE_DIM_CAN_IGNORE -> reference/c-api/types-and-structures.html#c.UFUNC_CORE_DIM_CAN_IGNORE (-)
#   UFUNC_CORE_DIM_SIZE_INFERRED -> reference/c-api/types-and-structures.html#c.UFUNC_CORE_DIM_SIZE_INFERRED (-)
#   UFUNC_FPE_DIVIDEBYZERO -> reference/c-api/ufunc.html#c.UFUNC_FPE_DIVIDEBYZERO (-)
#   UFUNC_FPE_INVALID -> reference/c-api/ufunc.html#c.UFUNC_FPE_INVALID (-)
#   UFUNC_FPE_OVERFLOW -> reference/c-api/ufunc.html#c.UFUNC_FPE_OVERFLOW (-)
#   UFUNC_FPE_UNDERFLOW -> reference/c-api/ufunc.html#c.UFUNC_FPE_UNDERFLOW (-)
#   import_array -> reference/c-api/array.html#c.import_array (-)
#   import_ufunc -> reference/c-api/ufunc.html#c.import_ufunc (-)
#   npy_copysign -> reference/c-api/coremath.html#c.npy_copysign (-)
#   npy_isfinite -> reference/c-api/coremath.html#c.npy_isfinite (-)
#   npy_isinf -> reference/c-api/coremath.html#c.npy_isinf (-)
#   npy_isnan -> reference/c-api/coremath.html#c.npy_isnan (-)
#   npy_signbit -> reference/c-api/coremath.html#c.npy_signbit (-)
#
# Category: c:type
#   NPY_AO -> reference/c-api/types-and-structures.html#c.NPY_AO (-)
#   NpyAuxData -> reference/c-api/array.html#c.NpyAuxData (-)
#   NpyAuxData_CloneFunc -> reference/c-api/array.html#c.NpyAuxData_CloneFunc (-)
#   NpyAuxData_FreeFunc -> reference/c-api/array.html#c.NpyAuxData_FreeFunc (-)
#   NpyIter -> reference/c-api/iterator.html#c.NpyIter (-)
#   NpyIter_GetMultiIndexFunc -> reference/c-api/iterator.html#c.NpyIter_GetMultiIndexFunc (-)
#   NpyIter_IterNextFunc -> reference/c-api/iterator.html#c.NpyIter_IterNextFunc (-)
#   NpyIter_Type -> reference/c-api/iterator.html#c.NpyIter_Type (-)
#   PyArrayDTypeMeta_CommonDType -> reference/c-api/array.html#c.PyArrayDTypeMeta_CommonDType (-)
#   PyArrayDTypeMeta_CommonInstance -> reference/c-api/array.html#c.PyArrayDTypeMeta_CommonInstance (-)
#   PyArrayDTypeMeta_DefaultDescriptor -> reference/c-api/array.html#c.PyArrayDTypeMeta_DefaultDescriptor (-)
#   PyArrayDTypeMeta_DiscoverDescrFromPyobject -> reference/c-api/array.html#c.PyArrayDTypeMeta_DiscoverDescrFromPyobject (-)
#   PyArrayDTypeMeta_EnsureCanonical -> reference/c-api/array.html#c.PyArrayDTypeMeta_EnsureCanonical (-)
#   PyArrayDTypeMeta_FinalizeDescriptor -> reference/c-api/array.html#c.PyArrayDTypeMeta_FinalizeDescriptor (-)
#   PyArrayDTypeMeta_GetItem -> reference/c-api/array.html#c.PyArrayDTypeMeta_GetItem (-)
#   PyArrayDTypeMeta_SetItem -> reference/c-api/array.html#c.PyArrayDTypeMeta_SetItem (-)
#   PyArrayDTypeMeta_Spec -> reference/c-api/types-and-structures.html#c.PyArrayDTypeMeta_Spec (-)
#   PyArrayInterface -> reference/c-api/types-and-structures.html#c.PyArrayInterface (-)
#   PyArrayIterObject -> reference/c-api/types-and-structures.html#c.PyArrayIterObject (-)
#   PyArrayMapIterObject -> reference/c-api/types-and-structures.html#c.PyArrayMapIterObject (-)
#   PyArrayMethodObject_tag -> reference/c-api/types-and-structures.html#c.PyArrayMethodObject_tag (-)
#   PyArrayMethod_Context -> reference/c-api/types-and-structures.html#c.PyArrayMethod_Context (-)
#   PyArrayMethod_GetLoop -> reference/c-api/array.html#c.PyArrayMethod_GetLoop (-)
#   PyArrayMethod_GetReductionInitial -> reference/c-api/array.html#c.PyArrayMethod_GetReductionInitial (-)
#   PyArrayMethod_GetTraverseLoop -> reference/c-api/array.html#c.PyArrayMethod_GetTraverseLoop (-)
#   PyArrayMethod_PromoterFunction -> reference/c-api/array.html#c.PyArrayMethod_PromoterFunction (-)
#   PyArrayMethod_ResolveDescriptors -> reference/c-api/array.html#c.PyArrayMethod_ResolveDescriptors (-)
#   PyArrayMethod_Spec -> reference/c-api/types-and-structures.html#c.PyArrayMethod_Spec (-)
#   PyArrayMethod_StridedLoop -> reference/c-api/array.html#c.PyArrayMethod_StridedLoop (-)
#   PyArrayMethod_TranslateGivenDescriptors -> reference/c-api/array.html#c.PyArrayMethod_TranslateGivenDescriptors (-)
#   PyArrayMethod_TranslateLoopDescriptors -> reference/c-api/array.html#c.PyArrayMethod_TranslateLoopDescriptors (-)
#   PyArrayMethod_TraverseLoop -> reference/c-api/array.html#c.PyArrayMethod_TraverseLoop (-)
#   PyArrayMultiIterObject -> reference/c-api/types-and-structures.html#c.PyArrayMultiIterObject (-)
#   PyArrayNeighborhoodIterObject -> reference/c-api/types-and-structures.html#c.PyArrayNeighborhoodIterObject (-)
#   PyArrayObject -> reference/c-api/types-and-structures.html#c.PyArrayObject (-)
#   PyArray_ArrFuncs -> reference/c-api/types-and-structures.html#c.PyArray_ArrFuncs (-)
#   PyArray_Chunk -> reference/c-api/types-and-structures.html#c.PyArray_Chunk (-)
#   PyArray_DTypeMeta -> reference/c-api/types-and-structures.html#c.PyArray_DTypeMeta (-)
#   PyArray_DatetimeMetaData -> reference/c-api/datetimes.html#c.PyArray_DatetimeMetaData (-)
#   PyArray_Descr -> reference/c-api/types-and-structures.html#c.PyArray_Descr (-)
#   PyArray_Descr.npy_hash_t -> reference/c-api/types-and-structures.html#c.PyArray_Descr.npy_hash_t (-)
#   PyArray_DescrProto -> reference/c-api/types-and-structures.html#c.PyArray_DescrProto (-)
#   PyArray_Dims -> reference/c-api/types-and-structures.html#c.PyArray_Dims (-)
#   PyArray_RegisterCastFunc.PyArray_VectorUnaryFunc -> reference/c-api/array.html#c.PyArray_RegisterCastFunc.PyArray_VectorUnaryFunc (-)
#   PyArray_StringDTypeObject -> reference/c-api/strings.html#c.PyArray_StringDTypeObject (-)
#   PyDataMem_Handler -> reference/c-api/data_memory.html#c.PyDataMem_Handler (-)
#   PyDataType_SUBARRAY.PyArray_ArrayDescr -> reference/c-api/array.html#c.PyDataType_SUBARRAY.PyArray_ArrayDescr (-)
#   PyUFuncGenericFunction -> reference/c-api/ufunc.html#c.PyUFuncGenericFunction (-)
#   PyUFuncObject -> reference/c-api/types-and-structures.html#c.PyUFuncObject (-)
#   PyUFuncObject.type_resolver.PyUFunc_TypeResolutionFunc -> reference/c-api/types-and-structures.html#c.PyUFuncObject.type_resolver.PyUFunc_TypeResolutionFunc (-)
#   PyUFunc_Loop1d -> reference/c-api/types-and-structures.html#c.PyUFunc_Loop1d (-)
#   PyUFunc_On_Om.PyUFunc_PyFuncData -> reference/c-api/ufunc.html#c.PyUFunc_On_Om.PyUFunc_PyFuncData (-)
#   binomial_t -> reference/random/c-api.html#c.binomial_t (-)
#   bitgen_t -> reference/random/c-api.html#c.bitgen_t (-)
#   npy_bool -> reference/c-api/dtype.html#c.npy_bool (-)
#   npy_byte -> reference/c-api/dtype.html#c.npy_byte (-)
#   npy_cdouble -> reference/c-api/dtype.html#c.npy_cdouble (-)
#   npy_cfloat -> reference/c-api/dtype.html#c.npy_cfloat (-)
#   npy_clongdouble -> reference/c-api/dtype.html#c.npy_clongdouble (-)
#   npy_datetime -> reference/c-api/dtype.html#c.npy_datetime (-)
#   npy_datetimestruct -> reference/c-api/datetimes.html#c.npy_datetimestruct (-)
#   npy_double -> reference/c-api/dtype.html#c.npy_double (-)
#   npy_float -> reference/c-api/dtype.html#c.npy_float (-)
#   npy_half -> reference/c-api/dtype.html#c.npy_half (-)
#   npy_int -> reference/c-api/dtype.html#c.npy_int (-)
#   npy_int16 -> reference/c-api/dtype.html#c.npy_int16 (-)
#   npy_int32 -> reference/c-api/dtype.html#c.npy_int32 (-)
#   npy_int64 -> reference/c-api/dtype.html#c.npy_int64 (-)
#   npy_intp -> reference/c-api/dtype.html#c.npy_intp (-)
#   npy_long -> reference/c-api/dtype.html#c.npy_long (-)
#   npy_longdouble -> reference/c-api/dtype.html#c.npy_longdouble (-)
#   npy_longlong -> reference/c-api/dtype.html#c.npy_longlong (-)
#   npy_packed_static_string -> reference/c-api/strings.html#c.npy_packed_static_string (-)
#   npy_short -> reference/c-api/dtype.html#c.npy_short (-)
#   npy_static_string -> reference/c-api/strings.html#c.npy_static_string (-)
#   npy_string_allocator -> reference/c-api/strings.html#c.npy_string_allocator (-)
#   npy_timedelta -> reference/c-api/dtype.html#c.npy_timedelta (-)
#   npy_ubyte -> reference/c-api/dtype.html#c.npy_ubyte (-)
#   npy_uint -> reference/c-api/dtype.html#c.npy_uint (-)
#   npy_uint16 -> reference/c-api/dtype.html#c.npy_uint16 (-)
#   npy_uint32 -> reference/c-api/dtype.html#c.npy_uint32 (-)
#   npy_uint64 -> reference/c-api/dtype.html#c.npy_uint64 (-)
#   npy_uintp -> reference/c-api/dtype.html#c.npy_uintp (-)
#   npy_ulong -> reference/c-api/dtype.html#c.npy_ulong (-)
#   npy_ulonglong -> reference/c-api/dtype.html#c.npy_ulonglong (-)
#   npy_ushort -> reference/c-api/dtype.html#c.npy_ushort (-)
#
# Category: c:member
#   NPY_AO.base -> reference/c-api/types-and-structures.html#c.NPY_AO.base (-)
#   NPY_AO.data -> reference/c-api/types-and-structures.html#c.NPY_AO.data (-)
#   NPY_AO.descr -> reference/c-api/types-and-structures.html#c.NPY_AO.descr (-)
#   NPY_AO.dimensions -> reference/c-api/types-and-structures.html#c.NPY_AO.dimensions (-)
#   NPY_AO.flags -> reference/c-api/types-and-structures.html#c.NPY_AO.flags (-)
#   NPY_AO.nd -> reference/c-api/types-and-structures.html#c.NPY_AO.nd (-)
#   NPY_AO.strides -> reference/c-api/types-and-structures.html#c.NPY_AO.strides (-)
#   NPY_AO.weakreflist -> reference/c-api/types-and-structures.html#c.NPY_AO.weakreflist (-)
#   PyArrayDTypeMeta_Spec.casts -> reference/c-api/types-and-structures.html#c.PyArrayDTypeMeta_Spec.casts (-)
#   PyArrayDTypeMeta_Spec.flags -> reference/c-api/types-and-structures.html#c.PyArrayDTypeMeta_Spec.flags (-)
#   PyArrayDTypeMeta_Spec.slots -> reference/c-api/types-and-structures.html#c.PyArrayDTypeMeta_Spec.slots (-)
#   PyArrayDTypeMeta_Spec.typeobj -> reference/c-api/types-and-structures.html#c.PyArrayDTypeMeta_Spec.typeobj (-)
#   PyArrayDTypeMeta_Type -> reference/c-api/types-and-structures.html#c.PyArrayDTypeMeta_Type (-)
#   PyArrayDescr_Type -> reference/c-api/types-and-structures.html#c.PyArrayDescr_Type (-)
#   PyArrayInterface.data -> reference/c-api/types-and-structures.html#c.PyArrayInterface.data (-)
#   PyArrayInterface.descr -> reference/c-api/types-and-structures.html#c.PyArrayInterface.descr (-)
#   PyArrayInterface.flags -> reference/c-api/types-and-structures.html#c.PyArrayInterface.flags (-)
#   PyArrayInterface.itemsize -> reference/c-api/types-and-structures.html#c.PyArrayInterface.itemsize (-)
#   PyArrayInterface.nd -> reference/c-api/types-and-structures.html#c.PyArrayInterface.nd (-)
#   PyArrayInterface.shape -> reference/c-api/types-and-structures.html#c.PyArrayInterface.shape (-)
#   PyArrayInterface.strides -> reference/c-api/types-and-structures.html#c.PyArrayInterface.strides (-)
#   PyArrayInterface.two -> reference/c-api/types-and-structures.html#c.PyArrayInterface.two (-)
#   PyArrayInterface.typekind -> reference/c-api/types-and-structures.html#c.PyArrayInterface.typekind (-)
#   PyArrayIterObject.ao -> reference/c-api/types-and-structures.html#c.PyArrayIterObject.ao (-)
#   PyArrayIterObject.backstrides -> reference/c-api/types-and-structures.html#c.PyArrayIterObject.backstrides (-)
#   PyArrayIterObject.contiguous -> reference/c-api/types-and-structures.html#c.PyArrayIterObject.contiguous (-)
#   PyArrayIterObject.coordinates -> reference/c-api/types-and-structures.html#c.PyArrayIterObject.coordinates (-)
#   PyArrayIterObject.dataptr -> reference/c-api/types-and-structures.html#c.PyArrayIterObject.dataptr (-)
#   PyArrayIterObject.dims_m1 -> reference/c-api/types-and-structures.html#c.PyArrayIterObject.dims_m1 (-)
#   PyArrayIterObject.factors -> reference/c-api/types-and-structures.html#c.PyArrayIterObject.factors (-)
#   PyArrayIterObject.index -> reference/c-api/types-and-structures.html#c.PyArrayIterObject.index (-)
#   PyArrayIterObject.nd_m1 -> reference/c-api/types-and-structures.html#c.PyArrayIterObject.nd_m1 (-)
#   PyArrayIterObject.size -> reference/c-api/types-and-structures.html#c.PyArrayIterObject.size (-)
#   PyArrayIterObject.strides -> reference/c-api/types-and-structures.html#c.PyArrayIterObject.strides (-)
#   PyArrayIter_Type -> reference/c-api/types-and-structures.html#c.PyArrayIter_Type (-)
#   PyArrayMapIter_Type -> reference/c-api/types-and-structures.html#c.PyArrayMapIter_Type (-)
#   PyArrayMethod_Context.caller -> reference/c-api/types-and-structures.html#c.PyArrayMethod_Context.caller (-)
#   PyArrayMethod_Context.descriptors -> reference/c-api/types-and-structures.html#c.PyArrayMethod_Context.descriptors (-)
#   PyArrayMethod_Context.method -> reference/c-api/types-and-structures.html#c.PyArrayMethod_Context.method (-)
#   PyArrayMethod_Spec.casting -> reference/c-api/types-and-structures.html#c.PyArrayMethod_Spec.casting (-)
#   PyArrayMethod_Spec.dtypes -> reference/c-api/types-and-structures.html#c.PyArrayMethod_Spec.dtypes (-)
#   PyArrayMethod_Spec.flags -> reference/c-api/types-and-structures.html#c.PyArrayMethod_Spec.flags (-)
#   PyArrayMethod_Spec.name -> reference/c-api/types-and-structures.html#c.PyArrayMethod_Spec.name (-)
#   PyArrayMethod_Spec.nin -> reference/c-api/types-and-structures.html#c.PyArrayMethod_Spec.nin (-)
#   PyArrayMethod_Spec.nout -> reference/c-api/types-and-structures.html#c.PyArrayMethod_Spec.nout (-)
#   PyArrayMethod_Spec.slots -> reference/c-api/types-and-structures.html#c.PyArrayMethod_Spec.slots (-)
#   PyArrayMultiIterObject.dimensions -> reference/c-api/types-and-structures.html#c.PyArrayMultiIterObject.dimensions (-)
#   PyArrayMultiIterObject.index -> reference/c-api/types-and-structures.html#c.PyArrayMultiIterObject.index (-)
#   PyArrayMultiIterObject.iters -> reference/c-api/types-and-structures.html#c.PyArrayMultiIterObject.iters (-)
#   PyArrayMultiIterObject.nd -> reference/c-api/types-and-structures.html#c.PyArrayMultiIterObject.nd (-)
#   PyArrayMultiIterObject.numiter -> reference/c-api/types-and-structures.html#c.PyArrayMultiIterObject.numiter (-)
#   PyArrayMultiIterObject.size -> reference/c-api/types-and-structures.html#c.PyArrayMultiIterObject.size (-)
#   PyArrayMultiIter_Type -> reference/c-api/types-and-structures.html#c.PyArrayMultiIter_Type (-)
#   PyArrayNeighborhoodIter_Type -> reference/c-api/types-and-structures.html#c.PyArrayNeighborhoodIter_Type (-)
#   PyArray_ArrFuncs.argmax -> reference/c-api/types-and-structures.html#c.PyArray_ArrFuncs.argmax (-)
#   PyArray_ArrFuncs.argmin -> reference/c-api/types-and-structures.html#c.PyArray_ArrFuncs.argmin (-)
#   PyArray_ArrFuncs.argsort -> reference/c-api/types-and-structures.html#c.PyArray_ArrFuncs.argsort (-)
#   PyArray_ArrFuncs.cancastscalarkindto -> reference/c-api/types-and-structures.html#c.PyArray_ArrFuncs.cancastscalarkindto (-)
#   PyArray_ArrFuncs.cancastto -> reference/c-api/types-and-structures.html#c.PyArray_ArrFuncs.cancastto (-)
#   PyArray_ArrFuncs.cast -> reference/c-api/types-and-structures.html#c.PyArray_ArrFuncs.cast (-)
#   PyArray_ArrFuncs.castdict -> reference/c-api/types-and-structures.html#c.PyArray_ArrFuncs.castdict (-)
#   PyArray_ArrFuncs.compare -> reference/c-api/types-and-structures.html#c.PyArray_ArrFuncs.compare (-)
#   PyArray_ArrFuncs.copyswap -> reference/c-api/types-and-structures.html#c.PyArray_ArrFuncs.copyswap (-)
#   PyArray_ArrFuncs.copyswapn -> reference/c-api/types-and-structures.html#c.PyArray_ArrFuncs.copyswapn (-)
#   PyArray_ArrFuncs.dotfunc -> reference/c-api/types-and-structures.html#c.PyArray_ArrFuncs.dotfunc (-)
#   PyArray_ArrFuncs.fill -> reference/c-api/types-and-structures.html#c.PyArray_ArrFuncs.fill (-)
#   PyArray_ArrFuncs.fillwithscalar -> reference/c-api/types-and-structures.html#c.PyArray_ArrFuncs.fillwithscalar (-)
#   PyArray_ArrFuncs.fromstr -> reference/c-api/types-and-structures.html#c.PyArray_ArrFuncs.fromstr (-)
#   PyArray_ArrFuncs.getitem -> reference/c-api/types-and-structures.html#c.PyArray_ArrFuncs.getitem (-)
#   PyArray_ArrFuncs.nonzero -> reference/c-api/types-and-structures.html#c.PyArray_ArrFuncs.nonzero (-)
#   PyArray_ArrFuncs.scalarkind -> reference/c-api/types-and-structures.html#c.PyArray_ArrFuncs.scalarkind (-)
#   PyArray_ArrFuncs.scanfunc -> reference/c-api/types-and-structures.html#c.PyArray_ArrFuncs.scanfunc (-)
#   PyArray_ArrFuncs.setitem -> reference/c-api/types-and-structures.html#c.PyArray_ArrFuncs.setitem (-)
#   PyArray_ArrFuncs.sort -> reference/c-api/types-and-structures.html#c.PyArray_ArrFuncs.sort (-)
#   PyArray_Chunk.base -> reference/c-api/types-and-structures.html#c.PyArray_Chunk.base (-)
#   PyArray_Chunk.flags -> reference/c-api/types-and-structures.html#c.PyArray_Chunk.flags (-)
#   PyArray_Chunk.len -> reference/c-api/types-and-structures.html#c.PyArray_Chunk.len (-)
#   PyArray_Chunk.ptr -> reference/c-api/types-and-structures.html#c.PyArray_Chunk.ptr (-)
#   PyArray_DTypeMeta.dt_slots -> reference/c-api/types-and-structures.html#c.PyArray_DTypeMeta.dt_slots (-)
#   PyArray_DTypeMeta.flags -> reference/c-api/types-and-structures.html#c.PyArray_DTypeMeta.flags (-)
#   PyArray_DTypeMeta.scalar_type -> reference/c-api/types-and-structures.html#c.PyArray_DTypeMeta.scalar_type (-)
#   PyArray_DTypeMeta.singleton -> reference/c-api/types-and-structures.html#c.PyArray_DTypeMeta.singleton (-)
#   PyArray_DTypeMeta.super -> reference/c-api/types-and-structures.html#c.PyArray_DTypeMeta.super (-)
#   PyArray_DTypeMeta.type_num -> reference/c-api/types-and-structures.html#c.PyArray_DTypeMeta.type_num (-)
#   PyArray_DatetimeMetaData.base -> reference/c-api/datetimes.html#c.PyArray_DatetimeMetaData.base (-)
#   PyArray_DatetimeMetaData.num -> reference/c-api/datetimes.html#c.PyArray_DatetimeMetaData.num (-)
#   PyArray_Descr.alignment -> reference/c-api/types-and-structures.html#c.PyArray_Descr.alignment (-)
#   PyArray_Descr.byteorder -> reference/c-api/types-and-structures.html#c.PyArray_Descr.byteorder (-)
#   PyArray_Descr.c_metadata -> reference/c-api/types-and-structures.html#c.PyArray_Descr.c_metadata (-)
#   PyArray_Descr.elsize -> reference/c-api/types-and-structures.html#c.PyArray_Descr.elsize (-)
#   PyArray_Descr.flags -> reference/c-api/types-and-structures.html#c.PyArray_Descr.flags (-)
#   PyArray_Descr.hash -> reference/c-api/types-and-structures.html#c.PyArray_Descr.hash (-)
#   PyArray_Descr.kind -> reference/c-api/types-and-structures.html#c.PyArray_Descr.kind (-)
#   PyArray_Descr.metadata -> reference/c-api/types-and-structures.html#c.PyArray_Descr.metadata (-)
#   PyArray_Descr.type -> reference/c-api/types-and-structures.html#c.PyArray_Descr.type (-)
#   PyArray_Descr.type_num -> reference/c-api/types-and-structures.html#c.PyArray_Descr.type_num (-)
#   PyArray_Descr.typeobj -> reference/c-api/types-and-structures.html#c.PyArray_Descr.typeobj (-)
#   PyArray_Dims.len -> reference/c-api/types-and-structures.html#c.PyArray_Dims.len (-)
#   PyArray_Dims.ptr -> reference/c-api/types-and-structures.html#c.PyArray_Dims.ptr (-)
#   PyArray_StringDTypeObject.allocator -> reference/c-api/strings.html#c.PyArray_StringDTypeObject.allocator (-)
#   PyArray_StringDTypeObject.array_owned -> reference/c-api/strings.html#c.PyArray_StringDTypeObject.array_owned (-)
#   PyArray_StringDTypeObject.base -> reference/c-api/strings.html#c.PyArray_StringDTypeObject.base (-)
#   PyArray_StringDTypeObject.coerce -> reference/c-api/strings.html#c.PyArray_StringDTypeObject.coerce (-)
#   PyArray_StringDTypeObject.default_string -> reference/c-api/strings.html#c.PyArray_StringDTypeObject.default_string (-)
#   PyArray_StringDTypeObject.has_nan_na -> reference/c-api/strings.html#c.PyArray_StringDTypeObject.has_nan_na (-)
#   PyArray_StringDTypeObject.has_string_na -> reference/c-api/strings.html#c.PyArray_StringDTypeObject.has_string_na (-)
#   PyArray_StringDTypeObject.na_name -> reference/c-api/strings.html#c.PyArray_StringDTypeObject.na_name (-)
#   PyArray_StringDTypeObject.na_object -> reference/c-api/strings.html#c.PyArray_StringDTypeObject.na_object (-)
#   PyArray_Type -> reference/c-api/types-and-structures.html#c.PyArray_Type (-)
#   PyDataType_SUBARRAY.PyArray_ArrayDescr.base -> reference/c-api/array.html#c.PyDataType_SUBARRAY.PyArray_ArrayDescr.base (-)
#   PyDataType_SUBARRAY.PyArray_ArrayDescr.shape -> reference/c-api/array.html#c.PyDataType_SUBARRAY.PyArray_ArrayDescr.shape (-)
#   PyGenericArrType_Type -> reference/c-api/types-and-structures.html#c.PyGenericArrType_Type (-)
#   PyUFuncObject.core_dim_flags -> reference/c-api/types-and-structures.html#c.PyUFuncObject.core_dim_flags (-)
#   PyUFuncObject.core_dim_ixs -> reference/c-api/types-and-structures.html#c.PyUFuncObject.core_dim_ixs (-)
#   PyUFuncObject.core_dim_sizes -> reference/c-api/types-and-structures.html#c.PyUFuncObject.core_dim_sizes (-)
#   PyUFuncObject.core_enabled -> reference/c-api/types-and-structures.html#c.PyUFuncObject.core_enabled (-)
#   PyUFuncObject.core_num_dim_ix -> reference/c-api/types-and-structures.html#c.PyUFuncObject.core_num_dim_ix (-)
#   PyUFuncObject.core_num_dims -> reference/c-api/types-and-structures.html#c.PyUFuncObject.core_num_dims (-)
#   PyUFuncObject.core_offsets -> reference/c-api/types-and-structures.html#c.PyUFuncObject.core_offsets (-)
#   PyUFuncObject.core_signature -> reference/c-api/types-and-structures.html#c.PyUFuncObject.core_signature (-)
#   PyUFuncObject.data -> reference/c-api/types-and-structures.html#c.PyUFuncObject.data (-)
#   PyUFuncObject.doc -> reference/c-api/types-and-structures.html#c.PyUFuncObject.doc (-)
#   PyUFuncObject.functions -> reference/c-api/types-and-structures.html#c.PyUFuncObject.functions (-)
#   PyUFuncObject.identity -> reference/c-api/types-and-structures.html#c.PyUFuncObject.identity (-)
#   PyUFuncObject.identity_value -> reference/c-api/types-and-structures.html#c.PyUFuncObject.identity_value (-)
#   PyUFuncObject.iter_flags -> reference/c-api/types-and-structures.html#c.PyUFuncObject.iter_flags (-)
#   PyUFuncObject.name -> reference/c-api/types-and-structures.html#c.PyUFuncObject.name (-)
#   PyUFuncObject.nargs -> reference/c-api/types-and-structures.html#c.PyUFuncObject.nargs (-)
#   PyUFuncObject.nin -> reference/c-api/types-and-structures.html#c.PyUFuncObject.nin (-)
#   PyUFuncObject.nout -> reference/c-api/types-and-structures.html#c.PyUFuncObject.nout (-)
#   PyUFuncObject.ntypes -> reference/c-api/types-and-structures.html#c.PyUFuncObject.ntypes (-)
#   PyUFuncObject.obj -> reference/c-api/types-and-structures.html#c.PyUFuncObject.obj (-)
#   PyUFuncObject.op_flags -> reference/c-api/types-and-structures.html#c.PyUFuncObject.op_flags (-)
#   PyUFuncObject.ptr -> reference/c-api/types-and-structures.html#c.PyUFuncObject.ptr (-)
#   PyUFuncObject.type_resolver -> reference/c-api/types-and-structures.html#c.PyUFuncObject.type_resolver (-)
#   PyUFuncObject.types -> reference/c-api/types-and-structures.html#c.PyUFuncObject.types (-)
#   PyUFuncObject.userloops -> reference/c-api/types-and-structures.html#c.PyUFuncObject.userloops (-)
#   PyUFunc_Type -> reference/c-api/types-and-structures.html#c.PyUFunc_Type (-)
#   npy_static_string.buf -> reference/c-api/strings.html#c.npy_static_string.buf (-)
#   npy_static_string.size -> reference/c-api/strings.html#c.npy_static_string.size (-)
#
# Category: c:enum
#   NPY_ARRAYMETHOD_FLAGS -> reference/c-api/array.html#c.NPY_ARRAYMETHOD_FLAGS (-)
#   NPY_CASTING -> reference/c-api/array.html#c.NPY_CASTING (-)
#   NPY_CLIPMODE -> reference/c-api/array.html#c.NPY_CLIPMODE (-)
#   NPY_DATETIMEUNIT -> reference/c-api/datetimes.html#c.NPY_DATETIMEUNIT (-)
#   NPY_ORDER -> reference/c-api/array.html#c.NPY_ORDER (-)
#   NPY_SCALARKIND -> reference/c-api/array.html#c.NPY_SCALARKIND (-)
#   NPY_SEARCHSIDE -> reference/c-api/array.html#c.NPY_SEARCHSIDE (-)
#   NPY_SELECTKIND -> reference/c-api/array.html#c.NPY_SELECTKIND (-)
#   NPY_SORTKIND -> reference/c-api/array.html#c.NPY_SORTKIND (-)
#   NPY_TYPES -> reference/c-api/dtype.html#c.NPY_TYPES (-)
#
# Category: c:enumerator
#   NPY_ARRAYMETHOD_FLAGS.NPY_METH_IS_REORDERABLE -> reference/c-api/array.html#c.NPY_ARRAYMETHOD_FLAGS.NPY_METH_IS_REORDERABLE (-)
#   NPY_ARRAYMETHOD_FLAGS.NPY_METH_NO_FLOATINGPOINT_ERRORS -> reference/c-api/array.html#c.NPY_ARRAYMETHOD_FLAGS.NPY_METH_NO_FLOATINGPOINT_ERRORS (-)
#   NPY_ARRAYMETHOD_FLAGS.NPY_METH_REQUIRES_PYAPI -> reference/c-api/array.html#c.NPY_ARRAYMETHOD_FLAGS.NPY_METH_REQUIRES_PYAPI (-)
#   NPY_ARRAYMETHOD_FLAGS.NPY_METH_RUNTIME_FLAGS -> reference/c-api/array.html#c.NPY_ARRAYMETHOD_FLAGS.NPY_METH_RUNTIME_FLAGS (-)
#   NPY_ARRAYMETHOD_FLAGS.NPY_METH_SUPPORTS_UNALIGNED -> reference/c-api/array.html#c.NPY_ARRAYMETHOD_FLAGS.NPY_METH_SUPPORTS_UNALIGNED (-)
#   NPY_CASTING.NPY_EQUIV_CASTING -> reference/c-api/array.html#c.NPY_CASTING.NPY_EQUIV_CASTING (-)
#   NPY_CASTING.NPY_NO_CASTING -> reference/c-api/array.html#c.NPY_CASTING.NPY_NO_CASTING (-)
#   NPY_CASTING.NPY_SAFE_CASTING -> reference/c-api/array.html#c.NPY_CASTING.NPY_SAFE_CASTING (-)
#   NPY_CASTING.NPY_SAME_KIND_CASTING -> reference/c-api/array.html#c.NPY_CASTING.NPY_SAME_KIND_CASTING (-)
#   NPY_CASTING.NPY_UNSAFE_CASTING -> reference/c-api/array.html#c.NPY_CASTING.NPY_UNSAFE_CASTING (-)
#   NPY_CLIPMODE.NPY_CLIP -> reference/c-api/array.html#c.NPY_CLIPMODE.NPY_CLIP (-)
#   NPY_CLIPMODE.NPY_RAISE -> reference/c-api/array.html#c.NPY_CLIPMODE.NPY_RAISE (-)
#   NPY_CLIPMODE.NPY_WRAP -> reference/c-api/array.html#c.NPY_CLIPMODE.NPY_WRAP (-)
#   NPY_DATETIMEUNIT.NPY_FR_D -> reference/c-api/datetimes.html#c.NPY_DATETIMEUNIT.NPY_FR_D (-)
#   NPY_DATETIMEUNIT.NPY_FR_ERROR -> reference/c-api/datetimes.html#c.NPY_DATETIMEUNIT.NPY_FR_ERROR (-)
#   NPY_DATETIMEUNIT.NPY_FR_GENERIC -> reference/c-api/datetimes.html#c.NPY_DATETIMEUNIT.NPY_FR_GENERIC (-)
#   NPY_DATETIMEUNIT.NPY_FR_M -> reference/c-api/datetimes.html#c.NPY_DATETIMEUNIT.NPY_FR_M (-)
#   NPY_DATETIMEUNIT.NPY_FR_W -> reference/c-api/datetimes.html#c.NPY_DATETIMEUNIT.NPY_FR_W (-)
#   NPY_DATETIMEUNIT.NPY_FR_Y -> reference/c-api/datetimes.html#c.NPY_DATETIMEUNIT.NPY_FR_Y (-)
#   NPY_DATETIMEUNIT.NPY_FR_as -> reference/c-api/datetimes.html#c.NPY_DATETIMEUNIT.NPY_FR_as (-)
#   NPY_DATETIMEUNIT.NPY_FR_fs -> reference/c-api/datetimes.html#c.NPY_DATETIMEUNIT.NPY_FR_fs (-)
#   NPY_DATETIMEUNIT.NPY_FR_h -> reference/c-api/datetimes.html#c.NPY_DATETIMEUNIT.NPY_FR_h (-)
#   NPY_DATETIMEUNIT.NPY_FR_m -> reference/c-api/datetimes.html#c.NPY_DATETIMEUNIT.NPY_FR_m (-)
#   NPY_DATETIMEUNIT.NPY_FR_ms -> reference/c-api/datetimes.html#c.NPY_DATETIMEUNIT.NPY_FR_ms (-)
#   NPY_DATETIMEUNIT.NPY_FR_ns -> reference/c-api/datetimes.html#c.NPY_DATETIMEUNIT.NPY_FR_ns (-)
#   NPY_DATETIMEUNIT.NPY_FR_ps -> reference/c-api/datetimes.html#c.NPY_DATETIMEUNIT.NPY_FR_ps (-)
#   NPY_DATETIMEUNIT.NPY_FR_s -> reference/c-api/datetimes.html#c.NPY_DATETIMEUNIT.NPY_FR_s (-)
#   NPY_DATETIMEUNIT.NPY_FR_us -> reference/c-api/datetimes.html#c.NPY_DATETIMEUNIT.NPY_FR_us (-)
#   NPY_ORDER.NPY_ANYORDER -> reference/c-api/array.html#c.NPY_ORDER.NPY_ANYORDER (-)
#   NPY_ORDER.NPY_CORDER -> reference/c-api/array.html#c.NPY_ORDER.NPY_CORDER (-)
#   NPY_ORDER.NPY_FORTRANORDER -> reference/c-api/array.html#c.NPY_ORDER.NPY_FORTRANORDER (-)
#   NPY_ORDER.NPY_KEEPORDER -> reference/c-api/array.html#c.NPY_ORDER.NPY_KEEPORDER (-)
#   NPY_SCALARKIND.NPY_BOOL_SCALAR -> reference/c-api/array.html#c.NPY_SCALARKIND.NPY_BOOL_SCALAR (-)
#   NPY_SCALARKIND.NPY_COMPLEX_SCALAR -> reference/c-api/array.html#c.NPY_SCALARKIND.NPY_COMPLEX_SCALAR (-)
#   NPY_SCALARKIND.NPY_FLOAT_SCALAR -> reference/c-api/array.html#c.NPY_SCALARKIND.NPY_FLOAT_SCALAR (-)
#   NPY_SCALARKIND.NPY_INTNEG_SCALAR -> reference/c-api/array.html#c.NPY_SCALARKIND.NPY_INTNEG_SCALAR (-)
#   NPY_SCALARKIND.NPY_INTPOS_SCALAR -> reference/c-api/array.html#c.NPY_SCALARKIND.NPY_INTPOS_SCALAR (-)
#   NPY_SCALARKIND.NPY_NOSCALAR -> reference/c-api/array.html#c.NPY_SCALARKIND.NPY_NOSCALAR (-)
#   NPY_SCALARKIND.NPY_NSCALARKINDS -> reference/c-api/array.html#c.NPY_SCALARKIND.NPY_NSCALARKINDS (-)
#   NPY_SCALARKIND.NPY_OBJECT_SCALAR -> reference/c-api/array.html#c.NPY_SCALARKIND.NPY_OBJECT_SCALAR (-)
#   NPY_SEARCHSIDE.NPY_SEARCHLEFT -> reference/c-api/array.html#c.NPY_SEARCHSIDE.NPY_SEARCHLEFT (-)
#   NPY_SEARCHSIDE.NPY_SEARCHRIGHT -> reference/c-api/array.html#c.NPY_SEARCHSIDE.NPY_SEARCHRIGHT (-)
#   NPY_SELECTKIND.NPY_INTROSELECT -> reference/c-api/array.html#c.NPY_SELECTKIND.NPY_INTROSELECT (-)
#   NPY_SORTKIND.NPY_HEAPSORT -> reference/c-api/array.html#c.NPY_SORTKIND.NPY_HEAPSORT (-)
#   NPY_SORTKIND.NPY_MERGESORT -> reference/c-api/array.html#c.NPY_SORTKIND.NPY_MERGESORT (-)
#   NPY_SORTKIND.NPY_NSORTS -> reference/c-api/array.html#c.NPY_SORTKIND.NPY_NSORTS (-)
#   NPY_SORTKIND.NPY_QUICKSORT -> reference/c-api/array.html#c.NPY_SORTKIND.NPY_QUICKSORT (-)
#   NPY_SORTKIND.NPY_STABLESORT -> reference/c-api/array.html#c.NPY_SORTKIND.NPY_STABLESORT (-)
#   NPY_TYPES.NPY_BOOL -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_BOOL (-)
#   NPY_TYPES.NPY_BYTE -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_BYTE (-)
#   NPY_TYPES.NPY_CDOUBLE -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_CDOUBLE (-)
#   NPY_TYPES.NPY_CFLOAT -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_CFLOAT (-)
#   NPY_TYPES.NPY_CLONGDOUBLE -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_CLONGDOUBLE (-)
#   NPY_TYPES.NPY_COMPLEX128 -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_COMPLEX128 (-)
#   NPY_TYPES.NPY_COMPLEX64 -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_COMPLEX64 (-)
#   NPY_TYPES.NPY_DATETIME -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_DATETIME (-)
#   NPY_TYPES.NPY_DEFAULT_TYPE -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_DEFAULT_TYPE (-)
#   NPY_TYPES.NPY_DOUBLE -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_DOUBLE (-)
#   NPY_TYPES.NPY_FLOAT -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_FLOAT (-)
#   NPY_TYPES.NPY_FLOAT16 -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_FLOAT16 (-)
#   NPY_TYPES.NPY_FLOAT32 -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_FLOAT32 (-)
#   NPY_TYPES.NPY_FLOAT64 -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_FLOAT64 (-)
#   NPY_TYPES.NPY_HALF -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_HALF (-)
#   NPY_TYPES.NPY_INT -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_INT (-)
#   NPY_TYPES.NPY_INT16 -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_INT16 (-)
#   NPY_TYPES.NPY_INT32 -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_INT32 (-)
#   NPY_TYPES.NPY_INT64 -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_INT64 (-)
#   NPY_TYPES.NPY_INT8 -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_INT8 (-)
#   NPY_TYPES.NPY_INTP -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_INTP (-)
#   NPY_TYPES.NPY_LONG -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_LONG (-)
#   NPY_TYPES.NPY_LONGDOUBLE -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_LONGDOUBLE (-)
#   NPY_TYPES.NPY_LONGLONG -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_LONGLONG (-)
#   NPY_TYPES.NPY_MASK -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_MASK (-)
#   NPY_TYPES.NPY_OBJECT -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_OBJECT (-)
#   NPY_TYPES.NPY_SHORT -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_SHORT (-)
#   NPY_TYPES.NPY_STRING -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_STRING (-)
#   NPY_TYPES.NPY_TIMEDELTA -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_TIMEDELTA (-)
#   NPY_TYPES.NPY_UBYTE -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_UBYTE (-)
#   NPY_TYPES.NPY_UINT -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_UINT (-)
#   NPY_TYPES.NPY_UINT16 -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_UINT16 (-)
#   NPY_TYPES.NPY_UINT32 -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_UINT32 (-)
#   NPY_TYPES.NPY_UINT64 -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_UINT64 (-)
#   NPY_TYPES.NPY_UINT8 -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_UINT8 (-)
#   NPY_TYPES.NPY_UINTP -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_UINTP (-)
#   NPY_TYPES.NPY_ULONG -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_ULONG (-)
#   NPY_TYPES.NPY_ULONGLONG -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_ULONGLONG (-)
#   NPY_TYPES.NPY_UNICODE -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_UNICODE (-)
#   NPY_TYPES.NPY_USHORT -> reference/c-api/dtype.html#c.NPY_TYPES.NPY_USHORT (-)
# ...
#   reference/routines.bitwise -> reference/routines.bitwise.html (Bit-wise operations)
#   reference/routines.char -> reference/routines.char.html (Legacy fixed-width string functionality)
#   reference/routines.ctypeslib -> reference/routines.ctypeslib.html (ctypes foreign function interface (numpy.ctypeslib))
#   reference/routines.datetime -> reference/routines.datetime.html (Datetime support functions)
#   reference/routines.dtype -> reference/routines.dtype.html (Data type routines)
#   reference/routines.dtypes -> reference/routines.dtypes.html (Data type classes (numpy.dtypes))
#   reference/routines.emath -> reference/routines.emath.html (Mathematical functions with automatic domain)
#   reference/routines.err -> reference/routines.err.html (Floating point error handling)
#   reference/routines.exceptions -> reference/routines.exceptions.html (Exceptions and Warnings (numpy.exceptions))
#   reference/routines.fft -> reference/routines.fft.html (Discrete Fourier Transform (numpy.fft))
#   reference/routines.functional -> reference/routines.functional.html (Functional programming)
#   reference/routines.indexing -> reference/routines.indexing.html (Indexing routines)
#   reference/routines.io -> reference/routines.io.html (Input and output)
#   reference/routines.lib -> reference/routines.lib.html (Lib module (numpy.lib))
#   reference/routines.linalg -> reference/routines.linalg.html (Linear algebra (numpy.linalg))
#   reference/routines.logic -> reference/routines.logic.html (Logic functions)
#   reference/routines.ma -> reference/routines.ma.html (Masked array operations)
#   reference/routines.math -> reference/routines.math.html (Mathematical functions)
#   reference/routines.matlib -> reference/routines.matlib.html (Matrix library (numpy.matlib))
#   reference/routines.other -> reference/routines.other.html (Miscellaneous routines)
#   reference/routines.polynomials -> reference/routines.polynomials.html (Polynomials)
#   reference/routines.polynomials-package -> reference/routines.polynomials-package.html (numpy.polynomial)
#   reference/routines.polynomials.chebyshev -> reference/routines.polynomials.chebyshev.html (Chebyshev Series (numpy.polynomial.chebyshev))
#   reference/routines.polynomials.classes -> reference/routines.polynomials.classes.html (Using the convenience classes)
#   reference/routines.polynomials.hermite -> reference/routines.polynomials.hermite.html (Hermite Series, “Physicists” (numpy.polynomial.hermite))
#   reference/routines.polynomials.hermite_e -> reference/routines.polynomials.hermite_e.html (HermiteE Series, “Probabilists” (numpy.polynomial.hermite_e))
#   reference/routines.polynomials.laguerre -> reference/routines.polynomials.laguerre.html (Laguerre Series (numpy.polynomial.laguerre))
#   reference/routines.polynomials.legendre -> reference/routines.polynomials.legendre.html (Legendre Series (numpy.polynomial.legendre))
#   reference/routines.polynomials.poly1d -> reference/routines.polynomials.poly1d.html (Poly1d)
#   reference/routines.polynomials.polynomial -> reference/routines.polynomials.polynomial.html (Power Series (numpy.polynomial.polynomial))
#   reference/routines.polynomials.polyutils -> reference/routines.polynomials.polyutils.html (Polyutils)
#   reference/routines.rec -> reference/routines.rec.html (Record Arrays (numpy.rec))
#   reference/routines.set -> reference/routines.set.html (Set routines)
#   reference/routines.sort -> reference/routines.sort.html (Sorting, searching, and counting)
#   reference/routines.statistics -> reference/routines.statistics.html (Statistics)
#   reference/routines.strings -> reference/routines.strings.html (String functionality)
#   reference/routines.testing -> reference/routines.testing.html (Test support (numpy.testing))
#   reference/routines.version -> reference/routines.version.html (Version information)
#   reference/routines.window -> reference/routines.window.html (Window functions)
#   reference/security -> reference/security.html (NumPy security)
#   reference/simd/build-options -> reference/simd/build-options.html (CPU build options)
#   reference/simd/how-it-works -> reference/simd/how-it-works.html (How does the CPU dispatcher work?)
#   reference/simd/index -> reference/simd/index.html (CPU/SIMD optimizations)
#   reference/simd/simd-optimizations -> reference/simd/simd-optimizations.html (<no title>)
#   reference/swig -> reference/swig.html (NumPy and SWIG)
#   reference/swig.interface-file -> reference/swig.interface-file.html (numpy.i: a SWIG interface file for NumPy)
#   reference/swig.testing -> reference/swig.testing.html (Testing the numpy.i typemaps)
#   reference/testing -> reference/testing.html (Testing guidelines)
#   reference/typing -> reference/typing.html (Typing (numpy.typing))
#   reference/ufuncs -> reference/ufuncs.html (Universal functions (ufunc))
#   release -> release.html (Release notes)
#   release/1.10.0-notes -> release/1.10.0-notes.html (NumPy 1.10.0 Release Notes)
#   release/1.10.1-notes -> release/1.10.1-notes.html (NumPy 1.10.1 Release Notes)
#   release/1.10.2-notes -> release/1.10.2-notes.html (NumPy 1.10.2 Release Notes)
#   release/1.10.3-notes -> release/1.10.3-notes.html (NumPy 1.10.3 Release Notes)
#   release/1.10.4-notes -> release/1.10.4-notes.html (NumPy 1.10.4 Release Notes)
#   release/1.11.0-notes -> release/1.11.0-notes.html (NumPy 1.11.0 Release Notes)
#   release/1.11.1-notes -> release/1.11.1-notes.html (NumPy 1.11.1 Release Notes)
#   release/1.11.2-notes -> release/1.11.2-notes.html (NumPy 1.11.2 Release Notes)
#   release/1.11.3-notes -> release/1.11.3-notes.html (NumPy 1.11.3 Release Notes)
#   release/1.12.0-notes -> release/1.12.0-notes.html (NumPy 1.12.0 Release Notes)
#   release/1.12.1-notes -> release/1.12.1-notes.html (NumPy 1.12.1 Release Notes)
#   release/1.13.0-notes -> release/1.13.0-notes.html (NumPy 1.13.0 Release Notes)
#   release/1.13.1-notes -> release/1.13.1-notes.html (NumPy 1.13.1 Release Notes)
#   release/1.13.2-notes -> release/1.13.2-notes.html (NumPy 1.13.2 Release Notes)
#   release/1.13.3-notes -> release/1.13.3-notes.html (NumPy 1.13.3 Release Notes)
#   release/1.14.0-notes -> release/1.14.0-notes.html (NumPy 1.14.0 Release Notes)
#   release/1.14.1-notes -> release/1.14.1-notes.html (NumPy 1.14.1 Release Notes)
#   release/1.14.2-notes -> release/1.14.2-notes.html (NumPy 1.14.2 Release Notes)
#   release/1.14.3-notes -> release/1.14.3-notes.html (NumPy 1.14.3 Release Notes)
#   release/1.14.4-notes -> release/1.14.4-notes.html (NumPy 1.14.4 Release Notes)
#   release/1.14.5-notes -> release/1.14.5-notes.html (NumPy 1.14.5 Release Notes)
#   release/1.14.6-notes -> release/1.14.6-notes.html (NumPy 1.14.6 Release Notes)
#   release/1.15.0-notes -> release/1.15.0-notes.html (NumPy 1.15.0 Release Notes)
#   release/1.15.1-notes -> release/1.15.1-notes.html (NumPy 1.15.1 Release Notes)
#   release/1.15.2-notes -> release/1.15.2-notes.html (NumPy 1.15.2 Release Notes)
#   release/1.15.3-notes -> release/1.15.3-notes.html (NumPy 1.15.3 Release Notes)
#   release/1.15.4-notes -> release/1.15.4-notes.html (NumPy 1.15.4 Release Notes)
#   release/1.16.0-notes -> release/1.16.0-notes.html (NumPy 1.16.0 Release Notes)
#   release/1.16.1-notes -> release/1.16.1-notes.html (NumPy 1.16.1 Release Notes)
#   release/1.16.2-notes -> release/1.16.2-notes.html (NumPy 1.16.2 Release Notes)
#   release/1.16.3-notes -> release/1.16.3-notes.html (NumPy 1.16.3 Release Notes)
#   release/1.16.4-notes -> release/1.16.4-notes.html (NumPy 1.16.4 Release Notes)
#   release/1.16.5-notes -> release/1.16.5-notes.html (NumPy 1.16.5 Release Notes)
#   release/1.16.6-notes -> release/1.16.6-notes.html (NumPy 1.16.6 Release Notes)
#   release/1.17.0-notes -> release/1.17.0-notes.html (NumPy 1.17.0 Release Notes)
#   release/1.17.1-notes -> release/1.17.1-notes.html (NumPy 1.17.1 Release Notes)
#   release/1.17.2-notes -> release/1.17.2-notes.html (NumPy 1.17.2 Release Notes)
#   release/1.17.3-notes -> release/1.17.3-notes.html (NumPy 1.17.3 Release Notes)
#   release/1.17.4-notes -> release/1.17.4-notes.html (NumPy 1.17.4 Release Notes)
#   release/1.17.5-notes -> release/1.17.5-notes.html (NumPy 1.17.5 Release Notes)
#   release/1.18.0-notes -> release/1.18.0-notes.html (NumPy 1.18.0 Release Notes)
#   release/1.18.1-notes -> release/1.18.1-notes.html (NumPy 1.18.1 Release Notes)
#   release/1.18.2-notes -> release/1.18.2-notes.html (NumPy 1.18.2 Release Notes)
#   release/1.18.3-notes -> release/1.18.3-notes.html (NumPy 1.18.3 Release Notes)
#   release/1.18.4-notes -> release/1.18.4-notes.html (NumPy 1.18.4 Release Notes)
#   release/1.18.5-notes -> release/1.18.5-notes.html (NumPy 1.18.5 Release Notes)
#   release/1.19.0-notes -> release/1.19.0-notes.html (NumPy 1.19.0 Release Notes)
#   release/1.19.1-notes -> release/1.19.1-notes.html (NumPy 1.19.1 Release Notes)
#   release/1.19.2-notes -> release/1.19.2-notes.html (NumPy 1.19.2 Release Notes)
#   release/1.19.3-notes -> release/1.19.3-notes.html (NumPy 1.19.3 Release Notes)
#   release/1.19.4-notes -> release/1.19.4-notes.html (NumPy 1.19.4 Release Notes)
#   release/1.19.5-notes -> release/1.19.5-notes.html (NumPy 1.19.5 Release Notes)
#   release/1.20.0-notes -> release/1.20.0-notes.html (NumPy 1.20.0 Release Notes)
#   release/1.20.1-notes -> release/1.20.1-notes.html (NumPy 1.20.1 Release Notes)
#   release/1.20.2-notes -> release/1.20.2-notes.html (NumPy 1.20.2 Release Notes)
#   release/1.20.3-notes -> release/1.20.3-notes.html (NumPy 1.20.3 Release Notes)
#   release/1.21.0-notes -> release/1.21.0-notes.html (NumPy 1.21.0 Release Notes)
#   release/1.21.1-notes -> release/1.21.1-notes.html (NumPy 1.21.1 Release Notes)
#   release/1.21.2-notes -> release/1.21.2-notes.html (NumPy 1.21.2 Release Notes)
#   release/1.21.3-notes -> release/1.21.3-notes.html (NumPy 1.21.3 Release Notes)
#   release/1.21.4-notes -> release/1.21.4-notes.html (NumPy 1.21.4 Release Notes)
#   release/1.21.5-notes -> release/1.21.5-notes.html (NumPy 1.21.5 Release Notes)
#   release/1.21.6-notes -> release/1.21.6-notes.html (NumPy 1.21.6 Release Notes)
#   release/1.22.0-notes -> release/1.22.0-notes.html (NumPy 1.22.0 Release Notes)
#   release/1.22.1-notes -> release/1.22.1-notes.html (NumPy 1.22.1 Release Notes)
#   release/1.22.2-notes -> release/1.22.2-notes.html (NumPy 1.22.2 Release Notes)
#   release/1.22.3-notes -> release/1.22.3-notes.html (NumPy 1.22.3 Release Notes)
#   release/1.22.4-notes -> release/1.22.4-notes.html (NumPy 1.22.4 Release Notes)
#   release/1.23.0-notes -> release/1.23.0-notes.html (NumPy 1.23.0 Release Notes)
#   release/1.23.1-notes -> release/1.23.1-notes.html (NumPy 1.23.1 Release Notes)
#   release/1.23.2-notes -> release/1.23.2-notes.html (NumPy 1.23.2 Release Notes)
#   release/1.23.3-notes -> release/1.23.3-notes.html (NumPy 1.23.3 Release Notes)
#   release/1.23.4-notes -> release/1.23.4-notes.html (NumPy 1.23.4 Release Notes)
#   release/1.23.5-notes -> release/1.23.5-notes.html (NumPy 1.23.5 Release Notes)
#   release/1.24.0-notes -> release/1.24.0-notes.html (NumPy 1.24 Release Notes)
#   release/1.24.1-notes -> release/1.24.1-notes.html (NumPy 1.24.1 Release Notes)
#   release/1.24.2-notes -> release/1.24.2-notes.html (NumPy 1.24.2 Release Notes)
#   release/1.24.3-notes -> release/1.24.3-notes.html (NumPy 1.24.3 Release Notes)
#   release/1.24.4-notes -> release/1.24.4-notes.html (NumPy 1.24.4 Release Notes)
#   release/1.25.0-notes -> release/1.25.0-notes.html (NumPy 1.25.0 Release Notes)
#   release/1.25.1-notes -> release/1.25.1-notes.html (NumPy 1.25.1 Release Notes)
#   release/1.25.2-notes -> release/1.25.2-notes.html (NumPy 1.25.2 Release Notes)
#   release/1.26.0-notes -> release/1.26.0-notes.html (NumPy 1.26.0 Release Notes)
#   release/1.26.1-notes -> release/1.26.1-notes.html (NumPy 1.26.1 Release Notes)
#   release/1.26.2-notes -> release/1.26.2-notes.html (NumPy 1.26.2 Release Notes)
#   release/1.26.3-notes -> release/1.26.3-notes.html (NumPy 1.26.3 Release Notes)
#   release/1.26.4-notes -> release/1.26.4-notes.html (NumPy 1.26.4 Release Notes)
#   release/1.3.0-notes -> release/1.3.0-notes.html (NumPy 1.3.0 Release Notes)
#   release/1.4.0-notes -> release/1.4.0-notes.html (NumPy 1.4.0 Release Notes)
#   release/1.5.0-notes -> release/1.5.0-notes.html (NumPy 1.5.0 Release Notes)
#   release/1.6.0-notes -> release/1.6.0-notes.html (NumPy 1.6.0 Release Notes)
#   release/1.6.1-notes -> release/1.6.1-notes.html (NumPy 1.6.1 Release Notes)
#   release/1.6.2-notes -> release/1.6.2-notes.html (NumPy 1.6.2 Release Notes)
#   release/1.7.0-notes -> release/1.7.0-notes.html (NumPy 1.7.0 Release Notes)
#   release/1.7.1-notes -> release/1.7.1-notes.html (NumPy 1.7.1 Release Notes)
#   release/1.7.2-notes -> release/1.7.2-notes.html (NumPy 1.7.2 Release Notes)
#   release/1.8.0-notes -> release/1.8.0-notes.html (NumPy 1.8.0 Release Notes)
#   release/1.8.1-notes -> release/1.8.1-notes.html (NumPy 1.8.1 Release Notes)
#   release/1.8.2-notes -> release/1.8.2-notes.html (NumPy 1.8.2 Release Notes)
#   release/1.9.0-notes -> release/1.9.0-notes.html (NumPy 1.9.0 Release Notes)
#   release/1.9.1-notes -> release/1.9.1-notes.html (NumPy 1.9.1 Release Notes)
#   release/1.9.2-notes -> release/1.9.2-notes.html (NumPy 1.9.2 Release Notes)
#   release/2.0.0-notes -> release/2.0.0-notes.html (NumPy 2.0.0 Release Notes)
#   release/2.1.0-notes -> release/2.1.0-notes.html (NumPy 2.1.0 Release Notes)
#   release/notes-towncrier -> release/notes-towncrier.html (Deprecations)
#   release/template -> release/template.html (NumPy 2.xx.x Release Notes)
#   user/absolute_beginners -> user/absolute_beginners.html (NumPy: the absolute basics for beginners)
#   user/basics -> user/basics.html (NumPy fundamentals)
#   user/basics.broadcasting -> user/basics.broadcasting.html (Broadcasting)
#   user/basics.copies -> user/basics.copies.html (Copies and views)
#   user/basics.creation -> user/basics.creation.html (Array creation)
#   user/basics.dispatch -> user/basics.dispatch.html (Writing custom array containers)
#   user/basics.indexing -> user/basics.indexing.html (Indexing on ndarrays)
#   user/basics.interoperability -> user/basics.interoperability.html (Interoperability with NumPy)
#   user/basics.io -> user/basics.io.html (I/O with NumPy)
#   user/basics.io.genfromtxt -> user/basics.io.genfromtxt.html (Importing data with genfromtxt)
#   user/basics.rec -> user/basics.rec.html (Structured arrays)
#   user/basics.strings -> user/basics.strings.html (Working with Arrays of Strings And Bytes)
#   user/basics.subclassing -> user/basics.subclassing.html (Subclassing ndarray)
#   user/basics.types -> user/basics.types.html (Data types)
#   user/basics.ufuncs -> user/basics.ufuncs.html (Universal functions (ufunc) basics)
#   user/byteswapping -> user/byteswapping.html (Byte-swapping)
#   user/c-info -> user/c-info.html (Using NumPy C-API)
#   user/c-info.beyond-basics -> user/c-info.beyond-basics.html (Beyond the basics)
#   user/c-info.how-to-extend -> user/c-info.how-to-extend.html (How to extend NumPy)
#   user/c-info.python-as-glue -> user/c-info.python-as-glue.html (Using Python as glue)
#   user/c-info.ufunc-tutorial -> user/c-info.ufunc-tutorial.html (Writing your own ufunc)
#   user/how-to-how-to -> user/how-to-how-to.html (How to write a NumPy how-to)
#   user/how-to-index -> user/how-to-index.html (How to index ndarrays)
#   user/how-to-io -> user/how-to-io.html (Reading and writing files)
#   user/how-to-partition -> user/how-to-partition.html (How to create arrays with regularly-spaced values)
#   user/how-to-verify-bug -> user/how-to-verify-bug.html (Verifying bugs and bug fixes in NumPy)
#   user/howtos_index -> user/howtos_index.html (NumPy how-tos)
#   user/index -> user/index.html (NumPy user guide)
#   user/install -> user/install.html (Installing NumPy)
#   user/misc -> user/misc.html (Miscellaneous)
#   user/numpy-for-matlab-users -> user/numpy-for-matlab-users.html (NumPy for MATLAB users)
#   user/quickstart -> user/quickstart.html (NumPy quickstart)
#   user/theory.broadcasting -> user/theory.broadcasting.html (Array broadcasting in Numpy)
#   user/troubleshooting-importerror -> user/troubleshooting-importerror.html (Troubleshooting)
#   user/whatisnumpy -> user/whatisnumpy.html (What is NumPy?)
